# %%
from dataloader import *
import numpy as np

# %%
import torchvision.transforms.functional as F

# %%
show = lambda x:F.to_pil_image(x[:,0,:])

# %%
dataloader = VideoDataLoader(batch_size = 10,
                                        num_workers = 4,
                                        sequence_step = 10,
                                        pin_memory = True,
                                        resize = 256)
train, test = dataloader(batch_size = 10,
                                        num_workers = 4,
                                        sequence_step = 10,
                                        pin_memory = True,
                                        resize = 256)
# Out:
# ===>Training Data : 9537
# ===>Testing Data : 3783

# %%
from utils import *

# %%
for i,data in enumerate(train):
    break

# %%
data.frames

# %%
x = data.frames

# %%
y = data.label

# %%
x.shape
# Out:
# torch.Size([10, 10, 3, 1, 256, 256])

# %%
x.shape
# Out:
# torch.Size([10, 10, 3, 1, 256, 256])

# %%
im = []
for i in range(10):
    for xi in x[:,i,:]:
      im.append(xi)  
im = iter(im)

# %%
show(x[:,9,:][1])
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F3305F3A780>

# %%
im = []
for xi in x[:,1,:]:
    im.append(xi)
im = iter(im)

# %%
show(next(im))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F3305F70390>

# %%
x[:,0,:].shape
# Out:
# torch.Size([10, 3, 1, 256, 256])
